# %%
import netCDF4 as nc
from netCDF4 import Dataset


src_data = Dataset(r'/home/jovyan/shared-public/QGreenland-Researcher-Workshop/group-seven/dataverse_files/GIS.nc')
print(src_data)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     featureType: timeSeries
#     title: Greenland discharge
#     summary: Greenland discharge
#     keywords: Greenland; Ice Discharge; Calving; Submarine Melt
#     source: git commit: 1626fab
#     creator_name: Ken Mankoff
#     creator_email: kdm@geus.dk
#     creator_url: http://kenmankoff.com
#     institution: GEUS
#     references: 10.22008/promice/ice_discharge
#     product_version: 2.0
#     dimensions(sizes): time(2719)
#     variables(dimensions): int64 time(time), float64 discharge(time), float64 err(time), float64 coverage(time)
#     groups:

# %%
print(src_data['discharge'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 discharge(time)
#     _FillValue: nan
#     long_name: Discharge
#     standard_name: land_ice_mass_tranport_due_to_calving_and_ice_front_melting
#     units: Gt yr-1
#     coordinates: time
# unlimited dimensions:
# current shape = (2719,)
# filling on

# %%
print(src_data['coverage'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 coverage(time)
#     _FillValue: nan
#     long_name: Coverage
#     standard_name: Coverage
#     coordinates: time
# unlimited dimensions:
# current shape = (2719,)
# filling on

# %%
print(src_data['err'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 err(time)
#     _FillValue: nan
#     long_name: Error
#     standard_name: Uncertainty
#     units: Gt yr-1
#     coordinates: time
# unlimited dimensions:
# current shape = (2719,)
# filling on

# %%
print(src_data['time'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int64 time(time)
#     long_name: time of measurement
#     standard_name: time
#     axis: T
#     cf_role: timeseries_id
#     units: days since 1986-04-15 00:00:00
#     calendar: proleptic_gregorian
# unlimited dimensions:
# current shape = (2719,)
# filling on, default _FillValue of -9223372036854775806 used
